# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\Shant\OneDrive\Documents\vehicle performnace analysis\vehicle_performance.csv')

# %%
df
# Out:
#      origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 0         1          8         307.0        130    3504          12.0  1970
# 1         1          8         350.0        165    3693          11.5  1970
# 2         1          8         318.0        150    3436          11.0  1970
# 3         1          8         304.0        150    3433          12.0  1970
# 4         1          8         302.0        140    3449          10.5  1970
# ..      ...        ...           ...        ...     ...           ...   ...
# 393       1          4         140.0         86    2790          15.6  1982
# 394       2          4          97.0         52    2130          24.6  1982
# 395       1          4         135.0         84    2295          11.6  1982
# 396       1          4         120.0         79    2625          18.6  1982
# 397       1          4         119.0         82    2720          19.4  1982
#
#                           name  Kilometer_per_liter
# ...

# %%
df.shape
# Out:
# (398, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   origin               398 non-null    int64
#  1   cylinders            398 non-null    int64
#  2   displacement         398 non-null    float64
#  3   horsepower           398 non-null    object
#  4   weight               398 non-null    int64
#  5   acceleration         398 non-null    float64
#  6   year                 398 non-null    int64
#  7   name                 398 non-null    object
#  8   Kilometer_per_liter  398 non-null    float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.origin.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 393    1
# 394    2
# 395    1
# 396    1
# 397    1
# Name: origin, Length: 398, dtype: int64>

# %%
df.origin.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 393    1
# 394    2
# 395    1
# 396    1
# 397    1
# Name: origin, Length: 398, dtype: int64>

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [origin, cylinders, displacement, horsepower, weight, acceleration, year, name, Kilometer_per_liter]
# Index: []

# %%
df['horsepower'].unique()
# Out:
# array(['130', '165', '150', '140', '198', '220', '215', '225', '190',
#        '170', '160', '95', '97', '85', '88', '46', '87', '90', '113',
#        '200', '210', '193', '?', '100', '105', '175', '153', '180', '110',
#        '72', '86', '70', '76', '65', '69', '60', '80', '54', '208', '155',
#        '112', '92', '145', '137', '158', '167', '94', '107', '230', '49',
#        '75', '91', '122', '67', '83', '78', '52', '61', '93', '148',
#        '129', '96', '71', '98', '115', '53', '81', '79', '120', '152',
#        '102', '108', '68', '58', '149', '89', '63', '48', '66', '139',
#        '103', '125', '133', '138', '135', '142', '77', '62', '132', '84',
#        '64', '74', '116', '82'], dtype=object)

# %%
df[df['horsepower']=='?']
# Out:
#      origin  cylinders  displacement horsepower  weight  acceleration  year  \
# 32        1          4          98.0          ?    2046          19.0  1971
# 126       1          6         200.0          ?    2875          17.0  1974
# 330       2          4          85.0          ?    1835          17.3  1980
# 336       1          4         140.0          ?    2905          14.3  1980
# 354       2          4         100.0          ?    2320          15.8  1981
# 374       1          4         151.0          ?    3035          20.5  1982
#
#                      name  Kilometer_per_liter
# 32             ford pinto            10.628593
# 126         ford maverick             8.928018
# 330  renault lecar deluxe            17.388378
# 336    ford mustang cobra            10.033391
# 354           renault 18i            14.667458
# 374        amc concord dl             9.778305

# %%
np.nan
# Out:
# nan

# %%
df['horsepower']=df['horsepower'].replace('?',np.nan)

# %%
df['horsepower']=df['horsepower'].fillna(0).astype('int64')

# %%
df
# Out:
#      origin  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0         1          8         307.0         130    3504          12.0  1970
# 1         1          8         350.0         165    3693          11.5  1970
# 2         1          8         318.0         150    3436          11.0  1970
# 3         1          8         304.0         150    3433          12.0  1970
# 4         1          8         302.0         140    3449          10.5  1970
# ..      ...        ...           ...         ...     ...           ...   ...
# 393       1          4         140.0          86    2790          15.6  1982
# 394       2          4          97.0          52    2130          24.6  1982
# 395       1          4         135.0          84    2295          11.6  1982
# 396       1          4         120.0          79    2625          18.6  1982
# 397       1          4         119.0          82    2720          19.4  1982
#
# ...

# %%
df.horsepower.mean()
# Out:
# np.float64(102.89447236180905)

# %%
df.horsepower.median()
# Out:
# np.float64(92.0)

# %%
sns.boxplot(x=df['horsepower'])
# Out:
# <Axes: xlabel='horsepower'>

# %%
df.isnull().sum()
# Out:
# origin                 0
# cylinders              0
# displacement           0
# horsepower             0
# weight                 0
# acceleration           0
# year                   0
# name                   0
# Kilometer_per_liter    0
# dtype: int64

# %%
sns.countplot(df['origin'],color='green')
# Out:
# <Axes: ylabel='count'>

# %%
df.groupby('origin')['Kilometer_per_liter'].mean()
# Out:
# origin
# 1     8.538388
# 2    11.857865
# 3    12.945895
# Name: Kilometer_per_liter, dtype: float64

# %%
df.groupby('cylinders')['Kilometer_per_liter'].mean().sort_values()
# Out:
# cylinders
# 8     6.361471
# 6     8.496801
# 3     8.736703
# 5    11.634766
# 4    12.451084
# Name: Kilometer_per_liter, dtype: float64

# %%
sns.distplot(df['displacement'])
# Out:
# C:\Users\Shant\AppData\Local\Temp\ipykernel_13444\2276503915.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['displacement'])
# <Axes: xlabel='displacement', ylabel='Density'>

# %%
sns.scatterplot(x=df['displacement'],y=df['Kilometer_per_liter'],data=df,hue='cylinders',color='red')
# Out:
# <Axes: xlabel='displacement', ylabel='Kilometer_per_liter'>
